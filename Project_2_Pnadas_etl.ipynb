# %%
from itsdangerous import json
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.inspection import inspect
from config import username, password, host, port, protocol
import seaborn as sns
import os

# %% [markdown]
# ### Extract CSVs into DataFrames for

# %% [markdown]
# #### View Head of Dataframe

# %%
# Read Deflator CSV Head
Deflator_file = "../Project_2_Inflation/DATA/Annual_Inflation_by_GDP_Deflator.csv"
Deflator_df = pd.read_csv(Deflator_file, compression='gzip')
Deflator_df.head()
# Out:
#                        Country Country_Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#    Percent_Annual_Inflation_in_Year_1961  \
# 0                                    NaN
# 1                               1.861701
# 2                                    NaN
# 3                               3.336148
# 4                                    NaN
#
#    Percent_Annual_Inflation_in_Year_1962  \
# 0                                    NaN
# 1                               0.979878
# 2                                    NaN
# 3                               2.432663
# 4                                    NaN
#
#    Percent_Annual_Inflation_in_Year_1963  \
# 0                                    NaN
# 1                               3.285364
# 2                                    NaN
# ...

# %%
# Read Unemployment CSV Head
Unemployment_file = "../Project_2_Inflation/DATA/inflation_interest_unemployment.csv"
Unemployment_df = pd.read_csv(Unemployment_file)
Unemployment_df.head()
# Out:
#        country  year  Inflation, consumer prices (annual %)  \
# 0  Afghanistan  1970                                    NaN
# 1  Afghanistan  1971                                    NaN
# 2  Afghanistan  1972                                    NaN
# 3  Afghanistan  1973                                    NaN
# 4  Afghanistan  1974                                    NaN
#
#    Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 0                                 NaN                     NaN
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
#
#    Deposit interest rate (%)  Lending interest rate (%)  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# ...

# %%
# Read Inflation CSV Head
Inflation_file = "../Project_2_Inflation/DATA/inflation.csv"
Inflation_df = pd.read_csv(Inflation_file)
Inflation_df.head()
# Out:
#    Unnamed: 0    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0           0  1913.0   9.8   9.8   9.8   9.8   9.7   9.8   9.9   9.9  10.0
# 1           1  1914.0  10.0   9.9   9.9   9.8   9.9   9.9  10.0  10.2  10.2
# 2           2  1915.0  10.1  10.0   9.9  10.0  10.1  10.1  10.1  10.1  10.1
# 3           3  1916.0  10.4  10.4  10.5  10.6  10.7  10.8  10.8  10.9  11.1
# 4           4  1917.0  11.7  12.0  12.0  12.6  12.8  13.0  12.8  13.0  13.3
#
#     Oct   Nov   Dec
# 0  10.0  10.1  10.0
# 1  10.1  10.2  10.1
# 2  10.2  10.3  10.3
# 3  11.3  11.5  11.6
# 4  13.5  13.5  13.7

# %%
# Read Deflator_2 Json Head
Deflator_2_file = os.path.join("../Project_2_Inflation/DATA/Annual_Inflation_by_GDP_Deflator-2.json")
with open(Deflation_2_file) as jsonfile:
Deflator_2_df = pd.read_json(Deflator_file, compression='gzip')
Deflator_2_df.head()
# Out:
#   Input In [5]
#     Deflator_2_df = pd.read_json(Deflator_file, compression='gzip')
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# #### View Tail of Dataframe

# %%
# Read Deflator CSV Tail
Deflator_df.tail()
# Out:
#           Country Country_Code  Percent_Annual_Inflation_in_Year_1961  \
# 261        Kosovo          XKX                                    NaN
# 262   Yemen, Rep.          YEM                                    NaN
# 263  South Africa          ZAF                               1.351841
# 264        Zambia          ZMB                              -3.655832
# 265      Zimbabwe          ZWE                              -2.041300
#
#      Percent_Annual_Inflation_in_Year_1962  \
# 261                                    NaN
# 262                                    NaN
# 263                               0.383169
# 264                               2.091562
# 265                               0.469618
#
#      Percent_Annual_Inflation_in_Year_1963  \
# 261                                    NaN
# 262                                    NaN
# 263                               3.274555
# 264                               0.403600
# 265                              -2.347740
#
# ...

# %%
# Read Unemployment CSV Tail
Unemployment_df.tail()
# Out:
#         country  year  Inflation, consumer prices (annual %)  \
# 13827  Zimbabwe  2017                               0.893962
# 13828  Zimbabwe  2018                              10.618866
# 13829  Zimbabwe  2019                             255.304991
# 13830  Zimbabwe  2020                             557.201817
# 13831  Zimbabwe  2021                                    NaN
#
#        Inflation, GDP deflator (annual %)  Real interest rate (%)  \
# 13827                            2.437608                4.370035
# 13828                           59.803356              -32.960315
# 13829                          440.829791              -78.517887
# 13830                          558.560024              -79.803157
# 13831                                 NaN                     NaN
#
#        Deposit interest rate (%)  Lending interest rate (%)  \
# 13827                   3.274167                   6.914167
# 13828                   2.532500                   7.131667
# ...

# %%
# Read Inflation CSV Tail

Inflation_df.tail()
# Out:
#      Unnamed: 0    Year      Jan      Feb      Mar      Apr      May      Jun  \
# 105         105  2018.0  247.867  248.991  249.554  250.546  251.588  251.989
# 106         106  2019.0  251.712  252.776  254.202  255.548  256.092  256.143
# 107         107  2020.0  257.971  258.678  258.115  256.389  256.394  257.797
# 108         108  2021.0  261.582  263.014  264.877  267.054  269.195  271.696
# 109         109  2022.0  281.148  283.716  287.504  289.109      NaN      NaN
#
#          Jul      Aug      Sep      Oct      Nov      Dec
# 105  252.006  252.146  252.439  252.885  252.038  251.233
# 106  256.571  256.558  256.759  257.346  257.208  256.974
# 107  259.101  259.918  260.280  260.388  260.229  260.474
# 108  273.003  273.567  274.310  276.589  277.948  278.802
# 109      NaN      NaN      NaN      NaN      NaN      NaN

# %%
# Read Deflator_2 Json tail
# Deflator_2_df.tail()

# %% [markdown]
# ### Print-out All Possible Graphs(Isaac Taught me this but it takes for ever)

# %%
# sns.pairplot(Deflator_df)

# %%
# sns.pairplot(Unemployment_df)

# %%
# sns.pairplot(Inflation_df)

# %%
# sns.pairplot(Deflator_2_df)

# %% [markdown]
# ### Transform Deflator DataFrame

# %%
# Create a filtered dataframe from specific columns
Deflator_cols = ["License Serial Number", "Premises Name", "County ID Code"]
Deflator_transformed= Deflator_df[Deflator_cols].copy()

# Rename the column headers
Deflator_transformed = Deflator_transformed.rename(columns={"License Serial Number": "id",
                                                          "Premises Name": "premise_name",
                                                          "County ID Code": "county_id"})

# Clean the data by dropping duplicates and setting the index
Deflator_transformed.drop_duplicates("id", inplace=True)
Deflator_transformed.set_index("id", inplace=True)

Deflator_transformed.head()

# %% [markdown]
# ### Transform Unemployment Dataframe

# %%
# Create a filtered dataframe from specific columns
Unemployment_cols = ["License Serial Number", "Premises Name", "County ID Code"]
Unemployment_transformed= Unemployment_df[Unemployment_cols].copy()

# Rename the column headers
Unemployment_transformed = Unemployment_transformed.rename(columns={"License Serial Number": "id",
                                                          "Premises Name": "premise_name",
                                                          "County ID Code": "county_id"})

# Clean the data by dropping duplicates and setting the index
Unemployment_transformed.drop_duplicates("id", inplace=True)
Unemployment_transformed.set_index("id", inplace=True)

Unemployment_transformed.head()

# %% [markdown]
# ### Transform Inflation Dataframe

# %%
# Create a filtered dataframe from specific columns
Inflation_cols = ["License Serial Number", "Premises Name", "County ID Code"]
Inflation_transformed= Inflation_df[Inflation_cols].copy()

# Rename the column headers
Inflation_transformed = Inflation_transformed.rename(columns={"License Serial Number": "id",
                                                          "Premises Name": "premise_name",
                                                          "County ID Code": "county_id"})

# Clean the data by dropping duplicates and setting the index
Inflation_transformed.drop_duplicates("id", inplace=True)
Inflation_transformed.set_index("id", inplace=True)

Inflation_transformed.head()

# %% [markdown]
# ### Transform Deflator_2 Dataframe

# %%
# Create a filtered dataframe from specific columns
Deflator_2_cols = ["License Serial Number", "Premises Name", "County ID Code"]
Deflator_2_transformed= Deflator_2_df[Deflator_cols].copy()

# Rename the column headers
Deflator_2_transformed = Deflator_2_transformed.rename(columns={"License Serial Number": "id",
                                                          "Premises Name": "premise_name",
                                                          "County ID Code": "county_id"})

# Clean the data by dropping duplicates and setting the index
Deflator_2_transformed.drop_duplicates("id", inplace=True)
Deflator_2_transformed.set_index("id", inplace=True)

Deflator_2_transformed.head()

# %% [markdown]
# ### Create database connection

# %% [markdown]
# ### Load DataFrames into database
